# %% [markdown]
# # Test

# %%
print('"presenter-notes" - should not appear')
# Out:
# "presenter-notes" - should not appear

# %%
print('no tags - should appear')
# Out:
# no tags - should appear

# %%
print('"remove-cell" - This should NOT appear')
# Out:
# "remove-cell" - This should NOT appear

# %%
print('multiple tags- This should NOT appear')
# Out:
# multiple tags- This should NOT appear
